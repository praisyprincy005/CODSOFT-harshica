# %% [markdown]
# <a href="https://colab.research.google.com/github/praisyprincy005/CODSOFT-harshica/blob/main4/TASK_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
user_choice=input("choose rock/paper/scissors=  ")

def get_computer_choice():
    choices = ['rock', 'paper', 'scissors']
    return random.choice(choices)

computer_choice = get_computer_choice()

print(f"You chose: {user_choice}")
print(f"Computer chose: {computer_choice}")

if user_choice==computer_choice:
  print("it's a tie")
elif (user_choice == 'rock' and computer_choice == 'scissors') or \
         (user_choice == 'scissors' and computer_choice == 'paper') or \
         (user_choice == 'paper' and computer_choice == 'rock'):
    print("you win")
else:
    print("you lose")
# Out:
# choose rock/paper/scissors=  paper
# You chose: paper
# Computer chose: scissors
# you lose
